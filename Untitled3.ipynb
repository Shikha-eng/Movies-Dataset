# %% [markdown]
# <a href="https://colab.research.google.com/github/Shikha-eng/Movies-Dataset/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
recipes = [
  {
    "id": 1,
    "name": "Paneer Butter Masala",
    "ingredients": ["paneer", "butter", "tomato", "cream", "spices"],
    "instructions": [
      "Heat butter in a pan",
      "Add tomato puree and cook",
      "Add spices and cream",
      "Add paneer cubes and simmer"
    ],
    "cuisine": "Indian",
    "prep_time": 10,
    "cook_time": 20,
    "difficulty": "medium",
    "diet": "veg",
    "calories": 400,
    "tags": ["curry", "north indian", "dinner"]
  },
  {
    "id": 2,
    "name": "Chicken Biryani",
    "ingredients": ["chicken", "rice", "yogurt", "spices", "onion"],
    "instructions": [
      "Marinate chicken",
      "Cook rice separately",
      "Layer rice and chicken",
      "Cook on low heat"
    ],
    "cuisine": "Indian",
    "prep_time": 30,
    "cook_time": 40,
    "difficulty": "hard",
    "diet": "non-veg",
    "calories": 600,
    "tags": ["rice", "spicy", "festival"]
  },
  {
    "id": 3,
    "name": "Veg Sandwich",
    "ingredients": ["bread", "tomato", "cucumber", "butter", "cheese"],
    "instructions": [
      "Apply butter on bread",
      "Add sliced vegetables",
      "Add cheese and grill"
    ],
    "cuisine": "Global",
    "prep_time": 5,
    "cook_time": 5,
    "difficulty": "easy",
    "diet": "veg",
    "calories": 200,
    "tags": ["snack", "quick", "breakfast"]
  },
  {
    "id": 4,
    "name": "Masala Dosa",
    "ingredients": ["rice batter", "potato", "onion", "spices"],
    "instructions": [
      "Prepare dosa batter",
      "Cook dosa on pan",
      "Add potato filling",
      "Fold and serve"
    ],
    "cuisine": "South Indian",
    "prep_time": 20,
    "cook_time": 15,
    "difficulty": "medium",
    "diet": "veg",
    "calories": 300,
    "tags": ["breakfast", "crispy", "traditional"]
  },
  {
    "id": 5,
    "name": "Pasta Alfredo",
    "ingredients": ["pasta", "cream", "garlic", "butter", "cheese"],
    "instructions": [
      "Boil pasta",
      "Prepare creamy sauce",
      "Mix pasta with sauce"
    ],
    "cuisine": "Italian",
    "prep_time": 10,
    "cook_time": 15,
    "difficulty": "easy",
    "diet": "veg",
    "calories": 500,
    "tags": ["pasta", "creamy", "dinner"]
  },
  {
    "id": 6,
    "name": "Grilled Chicken",
    "ingredients": ["chicken", "olive oil", "spices", "lemon"],
    "instructions": [
      "Marinate chicken",
      "Grill until cooked"
    ],
    "cuisine": "Global",
    "prep_time": 15,
    "cook_time": 25,
    "difficulty": "medium",
    "diet": "non-veg",
    "calories": 350,
    "tags": ["protein", "healthy", "dinner"]
  },
  {
    "id": 7,
    "name": "Fruit Salad",
    "ingredients": ["apple", "banana", "orange", "grapes"],
    "instructions": [
      "Chop fruits",
      "Mix and serve"
    ],
    "cuisine": "Global",
    "prep_time": 10,
    "cook_time": 0,
    "difficulty": "easy",
    "diet": "vegan",
    "calories": 150,
    "tags": ["healthy", "snack", "no-cook"]
  },
  {
    "id": 8,
    "name": "Rajma Chawal",
    "ingredients": ["rajma", "rice", "tomato", "onion", "spices"],
    "instructions": [
      "Cook rajma",
      "Prepare gravy",
      "Serve with rice"
    ],
    "cuisine": "Indian",
    "prep_time": 15,
    "cook_time": 30,
    "difficulty": "medium",
    "diet": "veg",
    "calories": 450,
    "tags": ["comfort food", "lunch"]
  },
  {
    "id": 9,
    "name": "Omelette",
    "ingredients": ["egg", "onion", "chili", "salt"],
    "instructions": [
      "Beat eggs",
      "Cook on pan"
    ],
    "cuisine": "Global",
    "prep_time": 5,
    "cook_time": 5,
    "difficulty": "easy",
    "diet": "non-veg",
    "calories": 180,
    "tags": ["breakfast", "protein"]
  },
  {
    "id": 10,
    "name": "Chole Bhature",
    "ingredients": ["chickpeas", "flour", "spices", "oil"],
    "instructions": [
      "Cook chole",
      "Prepare dough",
      "Fry bhature",
      "Serve together"
    ],
    "cuisine": "Indian",
    "prep_time": 20,
    "cook_time": 30,
    "difficulty": "hard",
    "diet": "veg",
    "calories": 700,
    "tags": ["street food", "spicy", "lunch"]
  }
]
with open("recipes.json", "w") as f:
    json.dump(recipes, f, indent=4)

print("JSON file created successfully!")
# Out:
# JSON file created successfully!

# %%
import pandas as pd
pd.read_json('recipes.json')
# Out:
#    id                  name                                ingredients  \
# 0   1  Paneer Butter Masala    [paneer, butter, tomato, cream, spices]
# 1   2       Chicken Biryani     [chicken, rice, yogurt, spices, onion]
# 2   3          Veg Sandwich  [bread, tomato, cucumber, butter, cheese]
# 3   4           Masala Dosa       [rice batter, potato, onion, spices]
# 4   5         Pasta Alfredo     [pasta, cream, garlic, butter, cheese]
# 5   6       Grilled Chicken        [chicken, olive oil, spices, lemon]
# 6   7           Fruit Salad            [apple, banana, orange, grapes]
# 7   8          Rajma Chawal       [rajma, rice, tomato, onion, spices]
# 8   9              Omelette                  [egg, onion, chili, salt]
# 9  10         Chole Bhature            [chickpeas, flour, spices, oil]
#
#                                         instructions       cuisine  prep_time  \
# 0  [Heat butter in a pan, Add tomato puree and co...        Indian         10
# ...

# %%
pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 88.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-linux_x86_64.whl size=247950 sha256=6c31e18cf924bef652a577ba19f9d75ae278e2b864271d18f08575de6b825503
#   Stored in directory: /root/.cache/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=02b18191a2ad4a23f1486ee70f1ebade&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 50.7884,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.717,
#    'vote_count': 29997},
#   {'adult': False,
#    'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 50.7884,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.717,
#   'vote_count': 29997},
#  {'adult': False,
#   'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_count','vote_average']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     50.7884
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     41.8091
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     27.9822
# 3  The true story of how businessman Oskar Schind...   1993-12-15     28.5479
# 4  The defense and the prosecution have rested an...   1957-04-10     22.5520
#
#    vote_count  vote_average
# 0       29997         8.717
# 1       22665         8.686
# 2       13725         8.572
# 3       17248         8.567
# 4        9844         8.556

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=02b18191a2ad4a23f1486ee70f1ebade&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_count','vote_average']]
  df = df.concat([temp_df],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_21562/3779451866.py in <cell line: 0>()
#       2   response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=02b18191a2ad4a23f1486ee70f1ebade&language=en-US&page={}'.format(i))
#       3   temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_count','vote_average']]
# ----> 4   df = df.concat([temp_df],ignore_index=True)
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
for i in range(1, 429):
    response = requests.get(
        'https://api.themoviedb.org/3/movie/top_rated?api_key=02b18191a2ad4a23f1486ee70f1ebade&language=en-US&page={}'.format(i)
    )

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id','title','overview','release_date','popularity','vote_count','vote_average']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  830788            The Invitation
# 8556  294793        All the Old Knives
# 8557    8914             Deep Blue Sea
# 8558     918                Blind Date
# 8559  758879    A Castle for Christmas
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.to_csv('movies.csv')
